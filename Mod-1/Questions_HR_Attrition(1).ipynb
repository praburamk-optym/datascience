# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;">Problem Statement
#
# Employee Attrition has always been a crucial concern for a company. Attrition means a loss to the company in terms of cost invested in training an employee. There are a few companies which were forced to close due to high level of attrition. To minimize attrition several companies tries to analyze and understand several factors which migh lead to an employee to leave the company.
# The IBM HR Attrition Case Study is a dataset which aims to identify important factors that might be influential in determining an employee who might leave the company. You are hired by the company and your objective is to undestand the data and to identify the patterns in the data which will help HR team to take decisive actions to reduce the attrition rate.
#
# There are two given dataset, Company_Data.csv contains information of an employee related to the company and Personal_Data cotains personal information of an employee.

# %% [markdown]
# ## Data Dictionary
#
# 1. EmpId-              Employee ID
# 2. AGE-                Employee Age
# 3. EducationField-     Field of Education
# 4. Gender        -     Employee Gender
# 5. MaritalStatus -     Employee Marital Status
# 6. DistanceFromHome-   Distance from home to work (in miles)
# 7. BusinessTravel-     Frequency of business travel
# 8. Department-         Department of the employee
# 9. HourlyRate-         Hourly rate of an employee
# 10. JobLevel-          Job Level of the employee. Higher job level means senior post
# 11. JobRole-           Job Role of an employee
# 12. JobSatisfaction-   Job Satisfaction level of  an employee
# 13. MonthlyRate-       Montly rate of an employee
# 14. NumCompaniesWorked-How many companies has the employee worked before
# 15. OverTime-          Does the employee gets overtime
# 16. PercentSalaryHike- Average percentage take for the employee
# 17. TotalWorkingYears- Total Years of Experience of an employee
# 18. WorkLifeBalance-   Work life balance of an employee (4 means highly satisfied)
# 19. YearsAtCompany-    Years employee have worked in current company
# 20. YearsInCurrentRole-Years employee have worked in current role
# 21. TotalWorkingYears- Total Years of Experience of an employee
# 22. YearsSinceLastPromotion-   Number of years since last promotion
# 23. YearsWithCurrManager- Number of years with current manager
# 24. Attrition-         Employee has left the company or not

# %% [markdown]
# ### Change your Working Directory

# %%
import os 
os.chdir("/Users/praburam.krishnamurthy/Downloads")
os.print(pwd)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 import os
#       2 os.chdir("/Users/praburam.krishnamurthy/Downloads")
# ----> 3 os.print(pwd)
#
# AttributeError: module 'os' has no attribute 'print'

# %% [markdown]
# ### Q1. Import all the necessary libraries (Numpy and Pandas)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Q2. Import both csv files (and name Company_Data as "company" and Personal_Data as "personal" )

# %% [markdown]
# Load the Data file into Python DataFrame using pandas read_csv method

# %%
company=pd.read_csv('/Users/praburam.krishnamurthy/GL/Mod-1/Company_Data.csv')
personal=pd.read_csv('/Users/praburam.krishnamurthy/GL/Mod-1/Personal_Data.csv')

# %% [markdown]
# ### Q3.  View Top 10 rows of both the datasets

# %% [markdown]
# Hint:Head function is used to view the top records. The number of records to be viewed, needs to be  given in the parenthesis. Default value is 5.

# %%
personal.head(10)
# Out:
#      EmpID  Age EducationField  Gender MaritalStatus  DistanceFromHome
# 0  2102210   41  Life Sciences  Female        Single                 1
# 1  2102211   49  Life Sciences    Male       Married                 8
# 2  2102212   37          Other    Male        Single                 2
# 3  2102213   33  Life Sciences  Female       Married                 3
# 4  2102214   27        Medical    Male       Married                 2
# 5  2102215   32  Life Sciences    Male        Single                 2
# 6  2102216   59        Medical  Female       Married                 3
# 7  2102217   30  Life Sciences    Male      Divorced                24
# 8  2102218   38  Life Sciences    Male        Single                23
# 9  2102219   36        Medical    Male       Married                27

# %%
company.head(10)
# Out:
#      EmpID     BusinessTravel              Department  HourlyRate  JobLevel  \
# 0  2102210      Travel_Rarely                   Sales          94       2.0
# 1  2102211  Travel_Frequently  Research & Development          61       2.0
# 2  2102212      Travel_Rarely  Research & Development          92       1.0
# 3  2102213  Travel_Frequently  Research & Development          56       1.0
# 4  2102214      Travel_Rarely  Research & Development          40       1.0
# 5  2102215  Travel_Frequently  Research & Development          79       1.0
# 6  2102216      Travel_Rarely  Research & Development          81       1.0
# 7  2102217      Travel_Rarely  Research & Development          67       1.0
# 8  2102218  Travel_Frequently  Research & Development          44       3.0
# 9  2102219      Travel_Rarely  Research & Development          94       2.0
#
#                      JobRole  JobSatisfaction  MonthlyRate  \
# 0            Sales Executive                4        19479
# 1         Research Scientist                2        24907
# 2      Laboratory Technician                3         2396
# 3         Research Scientist                3        23159
# 4      Laboratory Technician                2        16632
# 5      Laboratory Technician                4        11864
# 6      Laboratory Technician                1         9964
# 7      Laboratory Technician                3        13335
# 8     Manufacturing Director                3         8787
# 9  Healthcare Representative                3        16577
#
#    NumCompaniesWorked OverTime  PercentSalaryHike  TotalWorkingYears  \
# 0                   8      Yes                 11                  8
# 1                   1       No                 23                 10
# 2                   6      Yes                 15                  7
# 3                   1      Yes                 11                  8
# 4                   9       No                 12                  6
# 5                   0       No                 13                  8
# 6                   4      Yes                 20                 12
# 7                   1       No                 22                  1
# 8                   0       No                 21                 10
# 9                   6       No                 13                 17
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0              1.0               6                   4
# 1              3.0              10                   7
# 2              3.0               0                   0
# 3              3.0               8                   7
# 4              3.0               2                   2
# 5              2.0               7                   7
# 6              2.0               1                   0
# 7              3.0               1                   0
# 8              3.0               9                   7
# 9              2.0               7                   7
#
#    YearsSinceLastPromotion  YearsWithCurrManager Attrition
# 0                        0                     5       Yes
# 1                        1                     7        No
# 2                        0                     0       Yes
# 3                        3                     0        No
# 4                        2                     2        No
# 5                        3                     6        No
# 6                        0                     0        No
# 7                        0                     0        No
# 8                        1                     8        No
# 9                        7                     7        No

# %% [markdown]
# ### Q4. Merge both datasets and name the merged dataset as df
#
# Hint:Merge the datasets using pd.merge() command- Use how="outer" and on="EmpID"

# %%
df=pd.merge(personal,company,how='outer',on="EmpID")
df
# Out:
#         EmpID  Age EducationField  Gender MaritalStatus  DistanceFromHome  \
# 0     2102210   41  Life Sciences  Female        Single                 1
# 1     2102211   49  Life Sciences    Male       Married                 8
# 2     2102212   37          Other    Male        Single                 2
# 3     2102213   33  Life Sciences  Female       Married                 3
# 4     2102214   27        Medical    Male       Married                 2
# ...       ...  ...            ...     ...           ...               ...
# 1465  2103675   36        Medical    Male       Married                23
# 1466  2103676   39        Medical    Male       Married                 6
# 1467  2103677   27  Life Sciences    Male       Married                 4
# 1468  2103678   49        Medical    Male       Married                 2
# 1469  2103679   34        Medical    Male       Married                 8
#
#          BusinessTravel              Department  HourlyRate  JobLevel  ...  \
# 0         Travel_Rarely                   Sales          94       2.0  ...
# 1     Travel_Frequently  Research & Development          61       2.0  ...
# 2         Travel_Rarely  Research & Development          92       1.0  ...
# 3     Travel_Frequently  Research & Development          56       1.0  ...
# 4         Travel_Rarely  Research & Development          40       1.0  ...
# ...                 ...                     ...         ...       ...  ...
# 1465  Travel_Frequently  Research & Development          41       2.0  ...
# 1466      Travel_Rarely  Research & Development          42       3.0  ...
# 1467      Travel_Rarely  Research & Development          87       2.0  ...
# 1468  Travel_Frequently                   Sales          63       2.0  ...
# 1469      Travel_Rarely  Research & Development          82       2.0  ...
#
#      NumCompaniesWorked  OverTime  PercentSalaryHike  TotalWorkingYears  \
# 0                     8       Yes                 11                  8
# 1                     1        No                 23                 10
# 2                     6       Yes                 15                  7
# 3                     1       Yes                 11                  8
# 4                     9        No                 12                  6
# ...                 ...       ...                ...                ...
# 1465                  4        No                 17                 17
# 1466                  4        No                 15                  9
# 1467                  1       Yes                 20                  6
# 1468                  2        No                 14                 17
# 1469                  2        No                 12                  6
#
#      WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1.0               6                   4
# 1                3.0              10                   7
# 2                3.0               0                   0
# 3                3.0               8                   7
# 4                3.0               2                   2
# ...              ...             ...                 ...
# 1465             3.0               5                   2
# 1466             3.0               7                   7
# 1467             3.0               6                   2
# 1468             2.0               9                   6
# 1469             4.0               4                   3
#
#       YearsSinceLastPromotion  YearsWithCurrManager  Attrition
# 0                           0                     5        Yes
# 1                           1                     7         No
# 2                           0                     0        Yes
# 3                           3                     0         No
# 4                           2                     2         No
# ...                       ...                   ...        ...
# 1465                        0                     3         No
# 1466                        1                     7         No
# 1467                        0                     3         No
# 1468                        0                     8         No
# 1469                        1                     2         No
#
# [1470 rows x 23 columns]

# %% [markdown]
#  ### Q5. View Last 5 records of combined dataframe "df".

# %% [markdown]
# Hint:Tail function is used to view the last records. The number of records to be viewed, needs to be given in the parenthesis.Default value is 5.

# %%
df.tail(5)
# Out:
#         EmpID  Age EducationField Gender MaritalStatus  DistanceFromHome  \
# 1465  2103675   36        Medical   Male       Married                23
# 1466  2103676   39        Medical   Male       Married                 6
# 1467  2103677   27  Life Sciences   Male       Married                 4
# 1468  2103678   49        Medical   Male       Married                 2
# 1469  2103679   34        Medical   Male       Married                 8
#
#          BusinessTravel              Department  HourlyRate  JobLevel  ...  \
# 1465  Travel_Frequently  Research & Development          41       2.0  ...
# 1466      Travel_Rarely  Research & Development          42       3.0  ...
# 1467      Travel_Rarely  Research & Development          87       2.0  ...
# 1468  Travel_Frequently                   Sales          63       2.0  ...
# 1469      Travel_Rarely  Research & Development          82       2.0  ...
#
#      NumCompaniesWorked  OverTime  PercentSalaryHike  TotalWorkingYears  \
# 1465                  4        No                 17                 17
# 1466                  4        No                 15                  9
# 1467                  1       Yes                 20                  6
# 1468                  2        No                 14                 17
# 1469                  2        No                 12                  6
#
#      WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 1465             3.0               5                   2
# 1466             3.0               7                   7
# 1467             3.0               6                   2
# 1468             2.0               9                   6
# 1469             4.0               4                   3
#
#       YearsSinceLastPromotion  YearsWithCurrManager  Attrition
# 1465                        0                     3         No
# 1466                        1                     7         No
# 1467                        0                     3         No
# 1468                        0                     8         No
# 1469                        1                     2         No
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Q6. Display the shape/dimensions of dataset.

# %% [markdown]
# Displaying the shape of the Data Frame in which first value gives number of Rows and second value gives number of columns.
#
# Hint: Use "shape" function

# %%
df.shape
# Out:
# (1470, 23)

# %%
print("The number of rows are ",df.shape[0],"\nThe number of columns are",df.shape[1])
# Out:
# The number of rows are  1470
# The number of columns are 23

# %% [markdown]
# ### Q7. Check for missing values. Display number of null values per column.

# %% [markdown]
# Hint: use isnull() function

# %%
df.isnull().sum()
# Out:
# EmpID                      0
# Age                        0
# EducationField             0
# Gender                     0
# MaritalStatus              0
# DistanceFromHome           0
# BusinessTravel             0
# Department                 0
# HourlyRate                 0
# JobLevel                   6
# JobRole                    0
# JobSatisfaction            0
# MonthlyRate                0
# NumCompaniesWorked         0
# OverTime                   0
# PercentSalaryHike          0
# TotalWorkingYears          0
# WorkLifeBalance            4
# YearsAtCompany             0
# YearsInCurrentRole         0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# Attrition                  0
# dtype: int64

# %% [markdown]
# There are missing values present in the "Joblevel" and "WorklifeBalance" variables of the dataset.

# %% [markdown]
# ### Q8.  Drop null values from "df" and check if there are any missing value left after dropping null values

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# EmpID                      0
# Age                        0
# EducationField             0
# Gender                     0
# MaritalStatus              0
# DistanceFromHome           0
# BusinessTravel             0
# Department                 0
# HourlyRate                 0
# JobLevel                   0
# JobRole                    0
# JobSatisfaction            0
# MonthlyRate                0
# NumCompaniesWorked         0
# OverTime                   0
# PercentSalaryHike          0
# TotalWorkingYears          0
# WorkLifeBalance            0
# YearsAtCompany             0
# YearsInCurrentRole         0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# Attrition                  0
# dtype: int64

# %% [markdown]
# ### Q9. Check the datatype, number of non negative values and name of each variable in the dataset.
#
# Hint : Use info() function

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1460 entries, 0 to 1469
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmpID                    1460 non-null   int64
#  1   Age                      1460 non-null   int64
#  2   EducationField           1460 non-null   object
#  3   Gender                   1460 non-null   object
#  4   MaritalStatus            1460 non-null   object
#  5   DistanceFromHome         1460 non-null   int64
#  6   BusinessTravel           1460 non-null   object
#  7   Department               1460 non-null   object
#  8   HourlyRate               1460 non-null   int64
#  9   JobLevel                 1460 non-null   float64
#  10  JobRole                  1460 non-null   object
#  11  JobSatisfaction          1460 non-null   int64
#  12  MonthlyRate              1460 non-null   int64
#  13  NumCompaniesWorked       1460 non-null   int64
#  14  OverTime                 1460 non-null   object
#  15  PercentSalaryHike        1460 non-null   int64
#  16  TotalWorkingYears        1460 non-null   int64
#  17  WorkLifeBalance          1460 non-null   float64
#  18  YearsAtCompany           1460 non-null   int64
#  19  YearsInCurrentRole       1460 non-null   int64
#  20  YearsSinceLastPromotion  1460 non-null   int64
#  21  YearsWithCurrManager     1460 non-null   int64
#  22  Attrition                1460 non-null   object
# dtypes: float64(2), int64(13), object(8)
# memory usage: 273.8+ KB

# %% [markdown]
# ### Q10. Check the summary of the dataset
# Hint: To see the summary of a dataframe we will use describe function.

# %%
df.describe(include="all").T
# Out:
#                           count unique                     top  freq  \
# EmpID                    1460.0    NaN                     NaN   NaN
# Age                      1460.0    NaN                     NaN   NaN
# EducationField             1460      6           Life Sciences   600
# Gender                     1460      2                    Male   875
# MaritalStatus              1460      3                 Married   671
# DistanceFromHome         1460.0    NaN                     NaN   NaN
# BusinessTravel             1460      3           Travel_Rarely  1036
# Department                 1460      3  Research & Development   952
# HourlyRate               1460.0    NaN                     NaN   NaN
# JobLevel                 1460.0    NaN                     NaN   NaN
# JobRole                    1460      9         Sales Executive   325
# JobSatisfaction          1460.0    NaN                     NaN   NaN
# MonthlyRate              1460.0    NaN                     NaN   NaN
# NumCompaniesWorked       1460.0    NaN                     NaN   NaN
# OverTime                   1460      2                      No  1048
# PercentSalaryHike        1460.0    NaN                     NaN   NaN
# TotalWorkingYears        1460.0    NaN                     NaN   NaN
# WorkLifeBalance          1460.0    NaN                     NaN   NaN
# YearsAtCompany           1460.0    NaN                     NaN   NaN
# YearsInCurrentRole       1460.0    NaN                     NaN   NaN
# YearsSinceLastPromotion  1460.0    NaN                     NaN   NaN
# YearsWithCurrManager     1460.0    NaN                     NaN   NaN
# Attrition                  1460      2                      No  1225
#
#                                    mean          std        min         25%  \
# EmpID                    2102949.219178   422.080035  2102210.0  2102584.75
# Age                           36.910959     9.126498       18.0        30.0
# EducationField                      NaN          NaN        NaN         NaN
# Gender                              NaN          NaN        NaN         NaN
# MaritalStatus                       NaN          NaN        NaN         NaN
# DistanceFromHome               9.172603     8.101841        1.0         2.0
# BusinessTravel                      NaN          NaN        NaN         NaN
# Department                          NaN          NaN        NaN         NaN
# HourlyRate                    65.914384    20.316655       30.0        48.0
# JobLevel                       2.065753     1.107544        1.0         1.0
# JobRole                             NaN          NaN        NaN         NaN
# JobSatisfaction                2.729452     1.103963        1.0         2.0
# MonthlyRate                14299.465068  7123.418042     2094.0     8039.75
# NumCompaniesWorked             2.696575     2.499154        0.0         1.0
# OverTime                            NaN          NaN        NaN         NaN
# PercentSalaryHike             15.218493     3.666092       11.0        12.0
# TotalWorkingYears             11.286301     7.778828        0.0         6.0
# WorkLifeBalance                2.762329     0.707605        1.0         2.0
# YearsAtCompany                 7.028767      6.13939        0.0         3.0
# YearsInCurrentRole             4.243836     3.628309        0.0         2.0
# YearsSinceLastPromotion        2.197945     3.229596        0.0         0.0
# YearsWithCurrManager           4.133562     3.573852        0.0         2.0
# Attrition                           NaN          NaN        NaN         NaN
#
#                                50%         75%        max
# EmpID                    2102949.5  2103314.25  2103679.0
# Age                           36.0        43.0       60.0
# EducationField                 NaN         NaN        NaN
# Gender                         NaN         NaN        NaN
# MaritalStatus                  NaN         NaN        NaN
# DistanceFromHome               7.0        14.0       29.0
# BusinessTravel                 NaN         NaN        NaN
# Department                     NaN         NaN        NaN
# HourlyRate                    66.0        84.0      100.0
# JobLevel                       2.0         3.0        5.0
# JobRole                        NaN         NaN        NaN
# JobSatisfaction                3.0         4.0        4.0
# MonthlyRate                14225.5     20460.5    26999.0
# NumCompaniesWorked             2.0         4.0        9.0
# OverTime                       NaN         NaN        NaN
# PercentSalaryHike             14.0        18.0       25.0
# TotalWorkingYears             10.0        15.0       40.0
# WorkLifeBalance                3.0         3.0        4.0
# YearsAtCompany                 5.0        10.0       40.0
# YearsInCurrentRole             3.0         7.0       18.0
# YearsSinceLastPromotion        1.0         3.0       15.0
# YearsWithCurrManager           3.0         7.0       17.0
# Attrition                      NaN         NaN        NaN

# %% [markdown]
# ### Q11. Drop  the variable EmpID from the dataframe df.
# To drop any variable, use drop() function.

# %%
df.drop("EmpID",axis=1,inplace=True)

# %%
df.head()
# Out:
#    Age EducationField  Gender MaritalStatus  DistanceFromHome  \
# 0   41  Life Sciences  Female        Single                 1
# 1   49  Life Sciences    Male       Married                 8
# 2   37          Other    Male        Single                 2
# 3   33  Life Sciences  Female       Married                 3
# 4   27        Medical    Male       Married                 2
#
#       BusinessTravel              Department  HourlyRate  JobLevel  \
# 0      Travel_Rarely                   Sales          94       2.0
# 1  Travel_Frequently  Research & Development          61       2.0
# 2      Travel_Rarely  Research & Development          92       1.0
# 3  Travel_Frequently  Research & Development          56       1.0
# 4      Travel_Rarely  Research & Development          40       1.0
#
#                  JobRole  ...  NumCompaniesWorked  OverTime  \
# 0        Sales Executive  ...                   8       Yes
# 1     Research Scientist  ...                   1        No
# 2  Laboratory Technician  ...                   6       Yes
# 3     Research Scientist  ...                   1       Yes
# 4  Laboratory Technician  ...                   9        No
#
#    PercentSalaryHike TotalWorkingYears  WorkLifeBalance  YearsAtCompany  \
# 0                 11                 8              1.0               6
# 1                 23                10              3.0              10
# 2                 15                 7              3.0               0
# 3                 11                 8              3.0               8
# 4                 12                 6              3.0               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                   4                        0                     5
# 1                   7                        1                     7
# 2                   0                        0                     0
# 3                   7                        3                     0
# 4                   2                        2                     2
#
#    Attrition
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4         No
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Q12. Check how many employees left the company from the given dataset
# Hint :Use value_counts() function

# %%
df.Attrition.value_counts()
# Out:
# Attrition
# No     1225
# Yes     235
# Name: count, dtype: int64

# %% [markdown]
# df.Attrition.value_counts(normalize=True)

# %%
df.Attrition.value_counts(normalize=True)
# Out:
# Attrition
# No     0.839041
# Yes    0.160959
# Name: proportion, dtype: float64

# %% [markdown]
# ### Q13. Create a subset "df_new" from the dataset "df" which contain data of all the employees who have attrited. Also check the shape of the new dataset

# %%
df_new=df[df['Attrition']=='Yes']
df_new.head()
# Out:
#     Age EducationField  Gender MaritalStatus  DistanceFromHome  \
# 0    41  Life Sciences  Female        Single                 1
# 2    37          Other    Male        Single                 2
# 21   36  Life Sciences    Male        Single                 9
# 24   34        Medical    Male        Single                 6
# 26   32  Life Sciences  Female        Single                16
#
#        BusinessTravel              Department  HourlyRate  JobLevel  \
# 0       Travel_Rarely                   Sales          94       2.0
# 2       Travel_Rarely  Research & Development          92       1.0
# 21      Travel_Rarely                   Sales          82       1.0
# 24      Travel_Rarely  Research & Development          83       1.0
# 26  Travel_Frequently  Research & Development          72       1.0
#
#                   JobRole  ...  NumCompaniesWorked  OverTime  \
# 0         Sales Executive  ...                   8       Yes
# 2   Laboratory Technician  ...                   6       Yes
# 21   Sales Representative  ...                   7        No
# 24     Research Scientist  ...                   2        No
# 26     Research Scientist  ...                   1       Yes
#
#     PercentSalaryHike TotalWorkingYears  WorkLifeBalance  YearsAtCompany  \
# 0                  11                 8              1.0               6
# 2                  15                 7              3.0               0
# 21                 23                10              3.0               5
# 24                 11                 8              3.0               4
# 26                 22                10              3.0              10
#
#     YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                    4                        0                     5
# 2                    0                        0                     0
# 21                   3                        0                     3
# 24                   2                        1                     3
# 26                   2                        6                     7
#
#     Attrition
# 0         Yes
# 2         Yes
# 21        Yes
# 24        Yes
# 26        Yes
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Q14. Create the top 5 rows and first 5 columns in a matrix format. Use
#
# ---
#
# dataframe "df"
#
# Hint- use iloc function

# %%
df.iloc[0:5,0:5]
# Out:
#    Age EducationField  Gender MaritalStatus  DistanceFromHome
# 0   41  Life Sciences  Female        Single                 1
# 1   49  Life Sciences    Male       Married                 8
# 2   37          Other    Male        Single                 2
# 3   33  Life Sciences  Female       Married                 3
# 4   27        Medical    Male       Married                 2

# %% [markdown]
# ### Q15.  Analyze the mean for all the variables for employees who have attrited and whose who have not.
#
# Hint: Use groupby() function

# %%
df.groupby("Attrition").mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1871, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1870 try:
# -> 1871     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1872 except Exception as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/groupby/ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/groupby/ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     870 for i, group in enumerate(splitter):
# --> 871     res = func(group)
#     872     res = extract_result(res)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:2377, in GroupBy.mean.<locals>.<lambda>(x)
#    2374 else:
#    2375     result = self._cython_agg_general(
#    2376         "mean",
# -> 2377         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2378         numeric_only=numeric_only,
#    2379     )
#    2380     return result.__finalize__(self.obj, method="groupby")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/series.py:6221, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6213 @doc(make_doc("mean", ndim=1))
#    6214 def mean(
#    6215     self,
#    (...)
#    6219     **kwargs,
#    6220 ):
# -> 6221     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py:11978, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11971 def mean(
#   11972     self,
#   11973     axis: Axis | None = 0,
#    (...)
#   11976     **kwargs,
#   11977 ) -> Series | float:
# > 11978     return self._stat_function(
#   11979         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11980     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py:11935, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11933 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11935 return self._reduce(
#   11936     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11937 )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/series.py:6129, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6125     raise TypeError(
#    6126         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6127         "with non-numeric dtypes."
#    6128     )
# -> 6129 return op(delegate, skipna=skipna, **kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/nanops.py:1693, in _ensure_numeric(x)
#    1691 if isinstance(x, str):
#    1692     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1693     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1694 try:
#
# TypeError: Could not convert string 'Life SciencesLife SciencesMedicalLife SciencesMedicalLife SciencesLife SciencesMedicalMedicalLife SciencesLife SciencesMedicalLife SciencesLife SciencesOtherLife SciencesLife SciencesOtherMarketingMedicalMarketingMedicalOtherMedicalMedicalMarketingLife SciencesLife SciencesOtherLife SciencesLife SciencesMedicalMarketingLife SciencesMarketingLife SciencesMarketingMedicalMarketingLife SciencesLife SciencesMedicalLife SciencesLife SciencesMedicalLife SciencesMedicalLife SciencesTechnical DegreeLife SciencesMedicalLife SciencesLife SciencesLife SciencesMarketingOtherMedicalMedicalLife SciencesMedicalLife SciencesMedicalMedicalLife SciencesTechnical DegreeLife SciencesLife SciencesLife SciencesMarketingMedicalMedicalMedicalTechnical DegreeOtherMedicalMedicalMedicalLife SciencesOtherLife SciencesHuman ResourcesLife SciencesMedicalMedicalMedicalHuman ResourcesLife SciencesLife SciencesLife SciencesMedicalTechnical DegreeLife SciencesLife SciencesLife SciencesMarketingLife SciencesOtherTechnical DegreeMedicalMedicalMarketingLife SciencesLife SciencesMedicalLife SciencesLife SciencesHuman ResourcesMedicalTechnical DegreeLife SciencesMedicalTechnical DegreeMedicalLife SciencesLife SciencesMedicalMedicalMarketingMarketingLife SciencesMarketingTechnical DegreeMedicalMedicalMarketingMarketingMedicalMedicalMedicalLife SciencesMedicalLife SciencesLife SciencesLife SciencesLife SciencesLife SciencesTechnical DegreeMedicalMedicalLife SciencesLife SciencesLife SciencesMarketingLife SciencesMedicalMedicalMedicalMedicalMedicalMedicalMedicalLife SciencesMedicalLife SciencesMedicalMedicalMedicalLife SciencesMedicalMedicalLife SciencesTechnical DegreeTechnical DegreeLife SciencesMedicalMedicalLife SciencesMedicalLife SciencesMedicalLife SciencesLife SciencesLife SciencesLife SciencesMedicalMarketingLife SciencesMedicalOtherLife SciencesMedicalLife SciencesMarketingMedicalMarketingLife SciencesTechnical DegreeMedicalMedicalMarketingLife SciencesLife SciencesMedicalMarketingLife SciencesTechnical DegreeOtherMedicalLife SciencesLife SciencesMedicalLife SciencesTechnical DegreeLife SciencesLife SciencesMarketingLife SciencesMedicalMedicalLife SciencesLife SciencesLife SciencesTechnical DegreeTechnical DegreeMedicalMedicalLife SciencesMedicalLife SciencesMedicalMedicalMedicalMedicalMedicalLife SciencesMedicalLife SciencesLife SciencesMedicalLife SciencesLife SciencesTechnical DegreeMedicalLife SciencesLife SciencesLife SciencesLife SciencesTechnical DegreeMarketingMedicalMarketingMarketingLife SciencesMedicalLife SciencesMedicalMedicalTechnical DegreeMedicalLife SciencesLife SciencesLife SciencesLife SciencesTechnical DegreeHuman ResourcesLife SciencesLife SciencesLife SciencesMedicalLife SciencesTechnical DegreeLife SciencesTechnical DegreeLife SciencesMarketingMedicalMedicalLife SciencesMedicalMarketingLife SciencesLife SciencesMarketingLife SciencesLife SciencesOtherMedicalOtherMarketingMarketingMedicalLife SciencesMedicalMarketingTechnical DegreeLife SciencesMedicalMedicalLife SciencesLife SciencesTechnical DegreeMedicalMedicalMedicalTechnical DegreeLife SciencesOtherMedicalMedicalMedicalLife SciencesMedicalMedicalMedicalTechnical DegreeLife SciencesLife SciencesLife SciencesMedicalLife SciencesOtherLife SciencesLife SciencesLife SciencesMarketingTechnical DegreeMedicalMedicalLife SciencesMarketingLife SciencesLife SciencesLife SciencesMedicalMedicalMarketingMedicalMedicalOtherLife SciencesMedicalLife SciencesLife SciencesLife SciencesTechnical DegreeMarketingMedicalMedicalLife SciencesLife SciencesLife SciencesLife SciencesLife SciencesMedicalTechnical DegreeLife SciencesLife SciencesLife SciencesLife SciencesMedicalOtherMarketingLife SciencesMedicalMarketingMedicalLife SciencesLife SciencesLife SciencesLife SciencesMarketingLife SciencesMarketingLife SciencesOtherMedicalMarketingLife SciencesLife SciencesMarketingLife SciencesLife SciencesLife SciencesMedicalOtherTechnical DegreeMedicalLife SciencesOtherOtherMed ...
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df.groupby("Attrition").mean()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:2375, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2368     return self._numba_agg_general(
#    2369         grouped_mean,
#    2370         executor.float_dtype_mapping,
#    2371         engine_kwargs,
#    2372         min_periods=0,
#    2373     )
#    2374 else:
# -> 2375     result = self._cython_agg_general(
#    2376         "mean",
#    2377         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2378         numeric_only=numeric_only,
#    2379     )
#    2380     return result.__finalize__(self.obj, method="groupby")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1926, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1923     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1924     return result
# -> 1926 new_mgr = data.grouped_reduce(array_func)
#    1927 res = self._wrap_agged_manager(new_mgr)
#    1928 out = self._wrap_aggregated_output(res)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/internals/managers.py:1428, in BlockManager.grouped_reduce(self, func)
#    1424 if blk.is_object:
#    1425     # split on object-dtype blocks bc some columns may raise
#    1426     #  while others do not.
#    1427     for sb in blk._split():
# -> 1428         applied = sb.apply(func)
#    1429         result_blocks = extend_blocks(applied, result_blocks)
#    1430 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/internals/blocks.py:366, in Block.apply(self, func, **kwargs)
#     360 @final
#     361 def apply(self, func, **kwargs) -> list[Block]:
#     362     """
#     363     apply the function to my values; return a block if we are not
#     364     one
#     365     """
# --> 366     result = func(self.values, **kwargs)
#     368     result = maybe_coerce_values(result)
#     369     return self._split_op_result(result)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1923, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1920 else:
#    1921     return result
# -> 1923 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1924 return result
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1875, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1874     # preserve the kind of exception that raised
# -> 1875     raise type(err)(msg) from err
#    1877 if ser.dtype == object:
#    1878     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %% [markdown]
# ### Q16. Check the details of 5 employees who have spent maximum years in the company

# %%
df.sort_values(by="YearsAtCompany",ascending=False).head()
# Out:
#       Age EducationField  Gender MaritalStatus  DistanceFromHome  \
# 126    58        Medical  Female       Married                23
# 98     58        Medical    Male        Single                10
# 1116   55      Marketing    Male       Married                26
# 270    55        Medical    Male        Single                 1
# 561    52      Marketing    Male       Married                 3
#
#      BusinessTravel              Department  HourlyRate  JobLevel  \
# 126   Travel_Rarely  Research & Development          94       3.0
# 98    Travel_Rarely                   Sales          37       4.0
# 1116  Travel_Rarely                   Sales          60       5.0
# 270   Travel_Rarely  Research & Development          81       5.0
# 561   Travel_Rarely                   Sales          31       4.0
#
#                         JobRole  ...  NumCompaniesWorked  OverTime  \
# 126   Healthcare Representative  ...                   1        No
# 98              Sales Executive  ...                   0        No
# 1116                    Manager  ...                   1        No
# 270                     Manager  ...                   0       Yes
# 561                     Manager  ...                   1        No
#
#       PercentSalaryHike TotalWorkingYears  WorkLifeBalance  YearsAtCompany  \
# 126                  12                40              2.0              40
# 98                   13                38              2.0              37
# 1116                 21                36              3.0              36
# 270                  14                37              3.0              36
# 561                  11                34              4.0              34
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 126                   10                       15                     6
# 98                    10                        1                     8
# 1116                   6                        2                    13
# 270                   10                        4                    13
# 561                    6                        1                    16
#
#       Attrition
# 126         Yes
# 98           No
# 1116         No
# 270          No
# 561          No
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Q17.  Find out the minimum "Percentage Salary Hike" the company has offered?

# %%
df.PercentSalaryHike.min()
# Out:
# 11

# %% [markdown]
# ### Q18. What is the maximum Total Working Years of an employee?

# %%
df.TotalWorkingYears.max()

# %% [markdown]
# ### Q19. What percentage of employees stay in the company given they have spend more than 7 years with the current manager?

# %%
df[df["YearsWithCurrManager"]>7]["Attrition"].value_counts(normalize=True)
# Out:
# Attrition
# No     0.918519
# Yes    0.081481
# Name: proportion, dtype: float64

# %% [markdown]
# ### Q20.  What percentage of employees lives >10 miles from the company?

# %%
df[df['DistanceFromHome']>10]['DistanceFromHome'].count()/df.shape[0] *100
# Out:
# 30.068493150684933

# %% [markdown]
# ### Q21. Create a copy of the dataset , remove the "Attrition" variable from the new dataset and check the shape of the dataset

# %%
df_copy=df.copy()

# %%
df_copy.drop("Attrition",axis=1,inplace=True)

# %% [markdown]
# # END
